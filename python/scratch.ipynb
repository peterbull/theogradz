# %%
import torch

# %%
base = [1, 2, 3, 4, 5, 6]

# %%
a = torch.tensor(base).view(2, 3)
a
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
b = torch.tensor(base).view(3,2)
b
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
a @ b
# Out:
# tensor([[22, 28],
#         [49, 64]])
